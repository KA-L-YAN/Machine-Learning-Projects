# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob
import keras #library for neural network

import pandas as pd #loading data in table form  
import seaborn as sns #visualisation 
import matplotlib.pyplot as plt #visualisation
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import normalize #machine learning algorithm library
#Neural network module
from keras.models import Sequential 
from keras.layers import Dense,Activation,Dropout 
#from keras.layers.normalization import BatchNormalization 
from keras.utils import np_utils

model=Sequential()

model.add(Dense(3,activation='relu'))
model.compile(loss='mean_absolute_error',optimizer='adam')

#model.summary()

import tensorflow as tf

# %%
path = r"C:\Users\PAVAN KALYAN\Desktop\VS CODE\Preds"
csv_files = glob.glob(path + "/*.csv")
print(type(csv_files))
# Out:
# <class 'list'>

# %%
for file in csv_files:
    data=pd.read_csv(file)
    X=data.iloc[:,3:9].values
    Y=data.iloc[:,2].values
    model.add(tf.keras.layers.Dense(1, input_shape=(X.shape[1],), activation='relu'))
    model.fit(X,Y,validation_data=(X,Y),batch_size=10,epochs=50,verbose=1)
    y_pred=model.predict(X)
    df=pd.DataFrame(y_pred)
    data.insert(9,'LSTM', df)
    data.to_csv(file, index = False)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 1s 23ms/step - loss: 3.3032 - val_loss: 3.1817
# Epoch 2/50
# 19/19 [==============================] - 0s 7ms/step - loss: 3.0745 - val_loss: 2.9386
# Epoch 3/50
# 19/19 [==============================] - 0s 10ms/step - loss: 2.8188 - val_loss: 2.6682
# Epoch 4/50
# 19/19 [==============================] - 0s 8ms/step - loss: 2.5358 - val_loss: 2.3666
# Epoch 5/50
# 19/19 [==============================] - 0s 7ms/step - loss: 2.2238 - val_loss: 2.0411
# Epoch 6/50
# 19/19 [==============================] - 0s 9ms/step - loss: 1.8954 - val_loss: 1.7013
# Epoch 7/50
# 19/19 [==============================] - 0s 8ms/step - loss: 1.5288 - val_loss: 1.3160
# Epoch 8/50
# 19/19 [==============================] - 0s 8ms/step - loss: 1.1375 - val_loss: 0.9115
# Epoch 9/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.7256 - val_loss: 0.5175
# Epoch 10/50
# ...
